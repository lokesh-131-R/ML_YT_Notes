# %%
'''Data Preprocessing(DP)
->This is process of converting raw data to an meaning full data using different techiques.

Importance of DP:-
->Data in the real word are dirty,incomplete,noise,inconsistent,duplicate
a 
Data qulity elements:-
1)Accuracy
2)Completeness
3)consistency
4)Belivability
5)Interprebility

Machine learning algorthm follows the rule which is 
GIGO -Garbage In Garbage Out

Techinque in DP:-
1)Datacleaning 
2)Data integartion
3)Data Reduction
4)Data transformation
5)Data discrectization

Data cleaning:- Filling missing values,smoothing out the noise while identyfying outliers and correcting inconsistencies in the data
Data Integaration:- The tecnique to merge data from multiple sourcesinto a coherent data store,such as a data warehouse.
Data Reduction :- The tecnique se to reduce the data size by aggregating,eliminating rerduntant feacher or clustering for instance.
Data Transfromantion :-Data are transformed or consolidated into forms appriate for ML models training, such as normailzation,may be appplied where data are scaled to fall within a smaller range like 0.0 to0.1.
Data discretization:-Techique transforms numeric data by mapping valeus to interval or concept lables.Ex-1,2,3,4,5--->1-3,4-5


Feature Engineeing:-
 Feature--> This is an attrbute or property shared by all of the independrnt units on which analysis or prediction is to done.
 Engineering-->This is the process to creat feature/extract the feature from exising feature by domain knowledge to increase the performance of ML model.
 
 
 
 
 Variable and types of variable:-
 
 Variable-> It is an characteristic,number or quantity that cqan be measured or counted
 
 
 They have 4 type 
 1)Numerical
 2)Categorical
 3)Data and time
 4)Mixed

           -->Discrete
Numerical-->
           -->Continuous
  
  
              -->Ordinal
Categorical-->
              -->Nominal




NUmerical Variables:-
A numerical variable is a variable where the measurement or number has a numerical meaning 


Numerical Variable:-
1)Discrete variable:- The values which can be counted as whole values ex-1,34,56,78
2)continuous variable:-The values contain range measurements ex-1.3,34.6,56.4,78.4
 
Categorical Variable:-
The values of the categorical variable are select from a group of categorical,also know as the  labels.
 
 Categorical variables:-
 1)Ordinal variable:- This are categorical variable in which the categories can be meaningfull ordered Ex:- Rating of products,grading
 2)Nominal variable:- This is same as ordinal but there is nothing that indicates an intricsic order of thr lable and in principle Ex-Name,colour
 
Date and time:- This are variable which contain data only ,time only or both date and time Ex-jan-2022,logout,login.

Mixed Variables:- This variable which contains number and categories.
 









'''
# Out:
# 'Data Preprocessing(DP)\n->This is process of converting raw data to an meaning full data using different techiques.\n\nImportance of DP:-\n->Data in the real word are dirty,incomplete,noise,inconsistent,duplicate\na \nData qulity elements:-\n1) accuracy\n2)Completeness\n3)consistency\n4)Belivability\n5)Interprebility\n\nMachine learning algorthm follows the rule which is \nGIGO -Garbage In Garbage Out\n\nTechinque in DP:-\n1)Datacleaning \n2)Data integartion\n3)Data Reduction\n4)Data transformation\n5)Data discrectization\n\nData cleaning:- Filling missing values,smoothing out the noise while identyfying outliers and correcting inconsistencies in the data\nData Integaration:- The tecnique to merge data from multiple sourcesinto a coherent data store,such as a data warehouse.\n\n\n\n\n\n\n\n\n'
