# %%
# DATA CLEAING:-
#It is a prossess of detecting incomplete,incorrect,inaccurate and irrelevent parts of the data and then replaceing,modifing or deleting thr dirty data
# 1) Handling missing data 
''' In the variable or any pbservation values are not stored callled as missing values
    1-Ignoring missing value row or deleting the row.
    2-Filling the missing values manually.
    3-Global constance.
    4-Measure of central tendency(mean,median and mode).
    5-Measure of central tendency of each class.
    6-Most probable values(ML algorithims).
'''  
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ignoring missing values
  # reading of the data frame from the system 
df1=pd.read_csv(r"G:\Data science\ML_YT_Notes\house-prices-advanced-regression-techniques\train.csv")
df1 # calling the data frame
pd.set_option('display.max_columns',None)# to display all the columns 
df1
df1.shape # to know the shape of the df 
df1.info # to knoe the information of df
df1.isnull().sum() # to show number of null values in the columns
sns.heatmap(df1.isnull()) # to show how much there are null values in the data set all the white lines in the plot are null values
null_var=df1.isnull().sum()/df1.shape[0] *100 # this shows the values of null in the column in term of persentage(%)
drop_col=null_var[null_var>20]# this are the columns name where the null values are more than 20%
drop_col.keys()# to show only the columns name 
df1_drop=df1.drop(columns=drop_col.keys()) # to drop all the columns from the DF1 and saveing it to new variable 
sns.heatmap(df1_drop.isnull()) # to show df how much is it clean
df1_drop_row=df1_drop.dropna()
sns.heatmap(df1_drop_row.isnull())# when the heat plot is in same solid colour then the data is clean 
# to chech the data is cleaned properly or not use dist plot 
num_var=df1_drop_row.select_dtypes(include=['int64','float64']).columns
num_var
plt.figure(figsize=(25,25))
for i,var in enumerate (num_var):# this can only be used for the numerical data only 
    plt.subplot(9,4,i+1)
    sns.distplot(df1[var],bins=20)
    sns.distplot(df1_drop_row[var],bins=20)# this graph shows the diffrence or deviation of original and cleaned data for all the columns
pd.concate(df1[Street].value_counts()/df1_drop_row.shape[0]*100,df1_drop_row[Street].value_counts()/df1_drop_row.shape[0]*100)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# ...

# %%
# missing values filling 
'''Mean =average of the numbers given is know as the mean
   Median = when we arrange the number in the asending order the medial value is know as the median
'''
df1 # calling the df
df1.isnull().sum()# finding the number of null in each colums
df1_null=df1.isnull().sum()/df1.shape[0] * 100 # finding the persentage of null values
df1_drop_col=df1_null[df1_null>20].keys()# finding the columns how as null values more than 20%
df1_drop_col
df1_drop_cols=df1.drop(columns=df1_drop_col) # droping the columns whos  null values are more then 20%
df1_drop_cols
#sns.heatmap(df1_drop_cols.isnull()) # creating heatmap to see the null values
df1_col_name_null=df1_drop_cols.select_dtypes(include=['int64','float64']).keys() # getting the numerical values 
df1_col_name_null
'''for i,var in enumerate(df1_col_name_null):
    plt.subplot(9,4,i+1)
    sns.distplot(df1_drop_cols[var])'''
df1_num_val=df1_drop_cols.fillna(df1_drop_cols.mean()) # filling the null values with mean 
sns.heatmap(df1_num_val.isnull()); # creating
df1_null_value=df1_num_val.isnull().sum()
df1_nulls=df1_null_value[df1_null_value>0].keys()
df1_nulls
# Out:
# C:\Users\Lokesh\AppData\Local\Temp\ipykernel_15468\4157111287.py:18: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1_num_val=df1_drop_cols.fillna(df1_drop_cols.mean()) # filling the null values with mean
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15468\4157111287.py in <module>
#      23 for i in df1_nulls:
#      24     df1_final= df1_num_val[i].fillna(df1_num_val[i].mode(),inplace=True)
# ---> 25 df1_final.isnull().sum()
#
# AttributeError: 'NoneType' object has no attribute 'isnull'

# %%
df1.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object
